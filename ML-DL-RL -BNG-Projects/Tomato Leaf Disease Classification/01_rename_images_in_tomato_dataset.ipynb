# %% [markdown]
# <img src="../../images/course-banner.png">

# %%
# import the necessary packages
# !pip install imutils
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import cv2
import os
import sys
import tensorflow as tf
# Out:
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\byju\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\byju\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\byju\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\byju\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\byju\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\byju\anaconda3\lib\site-packages)
# ...

# %% [markdown]
# # DO NOT RENAME ONLY ONE TIME
#
# # IMAGES CAN BE DELETED

# %% [raw]
# sys.path.append('/Users/akoubaa/Desktop/car-project/')
# import riotu_computer_vision_lib
# from riotu_computer_vision_lib import *

# %%
#DATASET_PATH='C:/Users/Byju/Dropbox/1. BNGPersonal/0. MLDatasets/TLDarchive2/tomato2/All_data/Tomato___Bacterial_spot'
#DATASET_PATH='C:/Users/Byju/Dropbox/1. BNGPersonal/0. MLDatasets/TLDarchive2/tomato2/All_data/Tomato___Early_blight'
#DATASET_PATH='C:/Users/Byju/Dropbox/1. BNGPersonal/0. MLDatasets/TLDarchive2/tomato2/All_data/Tomato___healthy'
#DATASET_PATH='C:/Users/Byju/Dropbox/1. BNGPersonal/0. MLDatasets/TLDarchive2/tomato2/All_data/Tomato___Late_blight'
#DATASET_PATH='C:/Users/Byju/Dropbox/1. BNGPersonal/0. MLDatasets/TLDarchive2/tomato2/All_data/Tomato___Leaf_Mold'
#DATASET_PATH='C:/Users/Byju/Dropbox/1. BNGPersonal/0. MLDatasets/TLDarchive2/tomato2/All_data/Tomato___Septoria_leaf_spot'
#DATASET_PATH='C:/Users/Byju/Dropbox/1. BNGPersonal/0. MLDatasets/TLDarchive2/tomato2/All_data/Tomato___Spider_mites Two-spotted_spider_mite'
#DATASET_PATH='C:/Users/Byju/Dropbox/1. BNGPersonal/0. MLDatasets/TLDarchive2/tomato2/All_data/Tomato___Target_Spot'
#DATASET_PATH='C:/Users/Byju/Dropbox/1. BNGPersonal/0. MLDatasets/TLDarchive2/tomato2/All_data/Tomato___Tomato_mosaic_virus'
#DATASET_PATH='C:/Users/Byju/Dropbox/1. BNGPersonal/0. MLDatasets/TLDarchive2/tomato2/All_data/Tomato___Tomato_Yellow_Leaf_Curl_Virus'

#DATASET_PATH='C:/Users/Byju/Dropbox/1. BNGPersonal/0. MLDatasets/TLDarchive2/tomato/val/Tomato___Bacterial_spot'
#DATASET_PATH='C:/Users/Byju/Dropbox/1. BNGPersonal/0. MLDatasets/TLDarchive2/tomato/val/Tomato___Early_blight'
#DATASET_PATH='C:/Users/Byju/Dropbox/1. BNGPersonal/0. MLDatasets/TLDarchive2/tomato/val/Tomato___healthy'
#DATASET_PATH='C:/Users/Byju/Dropbox/1. BNGPersonal/0. MLDatasets/TLDarchive2/tomato/val/Tomato___Late_blight'
#DATASET_PATH='C:/Users/Byju/Dropbox/1. BNGPersonal/0. MLDatasets/TLDarchive2/tomato/val/Tomato___Leaf_Mold'
#DATASET_PATH='C:/Users/Byju/Dropbox/1. BNGPersonal/0. MLDatasets/TLDarchive2/tomato/val/Tomato___Septoria_leaf_spot'
#DATASET_PATH='C:/Users/Byju/Dropbox/1. BNGPersonal/0. MLDatasets/TLDarchive2/tomato/val/Tomato___Spider_mites Two-spotted_spider_mite'
#DATASET_PATH='C:/Users/Byju/Dropbox/1. BNGPersonal/0. MLDatasets/TLDarchive2/tomato/val/Tomato___Target_Spot'
#DATASET_PATH='C:/Users/Byju/Dropbox/1. BNGPersonal/0. MLDatasets/TLDarchive2/tomato/val/Tomato___Tomato_mosaic_virus'
#DATASET_PATH='C:/Users/Byju/Dropbox/1. BNGPersonal/0. MLDatasets/TLDarchive2/tomato/val/Tomato___Tomato_Yellow_Leaf_Curl_Virus'
print(DATASET_PATH)
# Out:
# C:/Users/Byju/Dropbox/1. BNGPersonal/0. MLDatasets/TLDarchive2/tomato2/All_data/Tomato___Late_blight

# %%
sys.path.append('C:/Users/Byju/Dropbox/2. Courses/Udemy/DL_II-Transfer_Learning/Section07/dataset-design-notebooks')
import anis_koubaa_udemy_computer_vision_lib  
from anis_koubaa_udemy_computer_vision_lib import *

# %%
def rename_dataset_images(folder_path):
    counter=1
    for folder,directory_name,files in os.walk(folder_path):
        print("/n................................files..................../n")
        print(files)
        counter=1
        folders_list =folder.split('/')
        print("/n................................folder list..................../n")
        print(folders_list)
        folder_name=folders_list[-1]
        print("/n................................folder name..................../n")
        print(folder_name)
        for name in files:
            #print(('.DS_Store' not in name))
            if ('.DS_Store' not in name):
                print(name)
                file_path = os.path.join(folder,name)
                print(file_path)
                print(folder)
                new_name = os.path.join(folder+"/"+folder_name+"-"+str(counter)+".jpg")
                #print(new_name)
                #print()
                os.rename(file_path, new_name)
                counter = counter +1
                #if counter==10:
                #    return 1
    print("counter = ", counter)
    return 1

# %%
rename_dataset_images(DATASET_PATH)
# Out:
# /n................................files..................../n
# ...
